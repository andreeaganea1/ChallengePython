# %%
cadena = "Bienvenido a mi aplicación."
print(cadena.capitalize())
# Out:
# Bienvenido a mi aplicación.

# %%
cadena = "Bienvenido A Mi Aplicación."
print(cadena.lower())
# Out:
# bienvenido a mi aplicación.

# %%
numeroFactura = 1575
#000000001575
print(numeroFactura)
